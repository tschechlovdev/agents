# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr
import os
load_dotenv(override=True)
# Out:
# True

# %%
load_dotenv(override=True)
google_api_key = os.environ.get("GEMINI_API_KEY")
openai = OpenAI(
    api_key=google_api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
from pydoc import Doc
from docling.document_converter import DocumentConverter

converter = DocumentConverter()
docling_text = converter.convert("me/Profile.pdf")

# %%
docling_text = docling_text.document.export_to_markdown()

# %%
docling_text
# Out:
# "Contact\n\ntschechd@gmail.com\n\nwww.linkedin.com/in/dennis-treder- tschechlov (LinkedIn)\n\nTop Skills\n\nIBM Cloud\n\nDevOps\n\nInfrastructure as code (IaC)\n\nCertifications\n\nIBM Machine Learning Specialist Advanced\n\nHashiCorp Certified: Terraform Associate (003)\n\nHow to Win a Data Science Competition: Learn from Top Kagglers\n\nGenerative AI with Large Language Models\n\nIntroduction to Deep Learning\n\n## Publications\n\nExploiting domain knowledge to address class imbalance and a heterogeneous feature space in multi-class classification\n\nAutoML4Clust: Efficient AutoML for Clustering Analyses\n\nEfficient Exploratory Clustering Analyses with Qualitative Approximations\n\nSDRank: A Deep Learning Approach for Similarity Ranking of Data Sources to Support User-Centric Data Analysis\n\nML2DAC: Meta-Learning to Democratize AutoML for Clustering Analysis\n\n## Dennis Treder-Tschechlov, PhD\n\nData&amp;AI || Platform Engineer || Client Engineering Sindelfingen, Baden-Württemberg, Germany\n\n## Summary\n\nI am a research scientist at the University of Stuttgart. I am fascinated by novel methods to automate and democratize machine learning approaches. In my PhD thesis, I am focusing on automating the unsupervised task of clustering analyses for novice analysts. This has led to publications at international top-conferences and journals such as SIGMOD or VLDB-journal. I love to learn new trending topics regarding data management, machine learning &amp; AI. For instance, I have completed Coursera Courses regarding Deep Learning and Reinforcement Learning.\n\n## Experience\n\n## IBM\n\nPlatform Engineer || Data&amp;AI and Automation || Client Engineering January 2025\xa0-\xa0Present\xa0(8 months)\n\nBöblingen, Baden-Württemberg, Germany\n\nInstitut für Parallele und Verteilte Systeme Research Scientist for Data &amp; AI March 2020\xa0-\xa0February 2025\xa0(5 years)\n\nStuttgart\n\n- Research on new methods for democratizing clustering analyses with\n\nAutoML, Meta-Learning, and Ensemble methods\n\n- Published 4 first-author papers, two of them at the at top-tier conferences\n\nSIGMOD and VLDB\n\n- 8 published co-author publications, two of them at the top-tier journal VLDB-\n\nJournal\n\n- Organization of events with industry partners Bosch, IBM, and Zeiss\n- Guided hands-on assignments for students about machine learning concepts and NoSQL systems\n- Supervision of over 20 student works, including student theses, practical courses,  data science projects, and seminar works\n\n## Software Campus\n\nLead of Software Campus Project 'VALID-PARTITION' January 2022\xa0-\xa0June 2024\xa0(2 years 6 months)\n\nStuttgart, Baden-Württemberg, Deutschland\n\n- Research grant of 100.000€ from German Federal Ministry of Education and Research (BMBF)\n- Cooperation with industry partner Trumpf SE + Co. KG\n- Managed budget, resources, and progress of the project\n- Application of developed methods for a real-world use case\n- Supervision of research scientists and student assistants\n\nRobert Bosch Smart Home GmbH Working Student Automated Testing April 2019\xa0-\xa0January 2020\xa0(10 months)\n\nStuttgart, Baden-Württemberg, Deutschland\n\n- Implementation of tools for process and workflow optimization\n- Automated and manuel testing of Android and iOS app\n\n## Universität Stuttgart\n\nStudent Research Assistant December 2017\xa0-\xa0March 2019\xa0(1 year 4 months)\n\nStuttgart\n\n- Research on state-of-the-art parameter optimization algorithms for clustering analyses\n- Implementation of selected state-of-the-art algorithms for clustering on\n\nApache Spark\n\nNovatec Software\n\nWorking Student Software Development February 2017\xa0-\xa0February 2018\xa0(1 year 1 month)\n\nStuttgart\n\nDevelopment, testing, and code reviews of web aplication for human ressource management.\n\n## Universität Stuttgart\n\nTutor 'Theoretical Foundations of Computer Science' August 2015\xa0-\xa0March 2017\xa0(1 year 8 months)\n\nStuttgart\n\nExplanations of ...

# %%
reader = PdfReader("me/Profile.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# tschechd@gmail.com
# www.linkedin.com/in/dennis-treder-
# tschechlov (LinkedIn)
# Top Skills
# IBM Cloud
# DevOps
# Infrastructure as code (IaC)
# Certifications
# IBM Machine Learning Specialist -
# Advanced
# HashiCorp Certified: Terraform
# Associate (003)
# How to Win a Data Science
# Competition: Learn from Top
# Kagglers
# Generative AI with Large Language
# Models
# Introduction to Deep Learning
# Publications
# Exploiting domain knowledge to
# address class imbalance and a
# heterogeneous feature space in
# multi-class classification
# AutoML4Clust: Efficient AutoML for
# Clustering Analyses
# Efficient Exploratory Clustering
# Analyses with Qualitative
# Approximations
# SDRank: A Deep Learning Approach
# for Similarity Ranking of Data
# Sources to Support User-Centric
# Data Analysis
# ML2DAC: Meta-Learning to
# Democratize AutoML for Clustering
# Analysis
# Dennis Treder-Tschechlov,
# PhD
# Data&AI || Platform Engineer || Client Engineering
# Sindelfingen, Baden-Württemberg, Germany
# Summary
# I am a research scientist at the University of Stuttgart. I am
# fascinated by novel methods to automate and democratize machine
# learning approaches. In my PhD thesis, I am focusing on automating
# the unsupervised task of clustering analyses for novice analysts.
# This has led to publications at international top-conferences and
# journals such as SIGMOD or VLDB-journal. I love to learn new
# trending topics regarding data management, machine learning & AI.
# For instance, I have completed Coursera Courses regarding Deep
# Learning and Reinforcement Learning.
# Experience
# IBM
# Platform Engineer || Data&AI and Automation || Client Engineering
# January 2025 - Present (8 months)
# Böblingen, Baden-Württemberg, Germany
# Institut für Parallele und Verteilte Systeme
# Research Scientist for Data & AI
# March 2020 - February 2025 (5 years)
# Stuttgart
# - Research on new methods for democratizing clustering analyses with
# AutoML, Meta-Learning, and Ensemble methods
# - Published 4 first-author papers, two of them at the at top-tier conferences
# SIGMOD and VLDB
# - 8 published co-author publications, two of them at the top-tier journal VLDB-
# Journal
# - Organization of events with industry partners Bosch, IBM, and Zeiss
# - Guided hands-on assignments for students about machine learning concepts
# and NoSQL systems
# - Supervision of over 20 student works, including student theses, practical
# courses,  data science projects, and seminar works
#   Page 1 of 3
# Software Campus
# Lead of Software Campus Project „VALID-PARTITION“
# January 2022 - June 2024 (2 years 6 months)
# Stuttgart, Baden-Württemberg, Deutschland
# - Research grant of 100.000€ from German Federal Ministry of Education and
# Research (BMBF)
# - Cooperation with industry partner Trumpf SE + Co. KG
# - Managed budget, resources, and progress of the project
# - Application of developed methods for a real-world use case
# - Supervision of research scientists and student assistants
# Robert Bosch Smart Home GmbH
# Working Student Automated Testing
# April 2019 - January 2020 (10 months)
# Stuttgart, Baden-Württemberg, Deutschland
# - Implementation of tools for process and workflow optimization
# - Automated and manuel testing of Android and iOS app
# Universität Stuttgart
# Student Research Assistant
# December 2017 - March 2019 (1 year 4 months)
# Stuttgart
# - Research on state-of-the-art parameter optimization algorithms for clustering
# analyses
# - Implementation of selected state-of-the-art algorithms for clustering on
# Apache Spark
# Novatec Software
# Working Student Software Development
# February 2017 - February 2018 (1 year 1 month)
# Stuttgart
# Development, testing, and code reviews of web aplication for human ressource
# management.
# Universität Stuttgart
# Tutor „Theoretical Foundations of Computer Science“
# August 2015 - March 2017 (1 year 8 months)
# Stuttgart
# Explanations of lecture contents and additional exercises
#   Page 2 of 3
# Education
# Universität Stuttgart
# Ph.D., Data Science/ Machine Learning · (March 2020 - October 2024)
# Universität Stuttgart
# Master of Science - MS, Software Engineering · (October 2017 - December
# 2019)
# Universität Stuttgart
# Bachelor of Science - BS, Software Engineering · (October 2013 - October
# 2017)
#   Page 3 of 3

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Dennis Treder-Tschechlov"

# %%
system_prompt
# Out:
# "You are acting as Dennis Treder-Tschechlov. You are answering questions on Dennis Treder-Tschechlov's website, particularly questions related to Dennis Treder-Tschechlov's career, background, skills and experience. Your responsibility is to represent Dennis Treder-Tschechlov for interactions on the website as faithfully as possible. You are given a summary of Dennis Treder-Tschechlov's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nI am a research scientist at the University of Stuttgart. I am fascinated by novel methods to automate and democratize machine learning approaches. In my PhD thesis, I am focusing on automating the unsupervised task of clustering analyses for novice analysts. This has led to publications at international top-conferences and journals such as SIGMOD or VLDB-journal. I love to learn new trending topics regarding data management, machine learning & AI. For instance, I have completed Coursera Courses regarding Deep Learning and Reinforcement Learning.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\ntschechd@gmail.com\nwww.linkedin.com/in/dennis-treder-\ntschechlov (LinkedIn)\nTop Skills\nIBM Cloud\nDevOps\nInfrastructure as code (IaC)\nCertifications\nIBM Machine Learning Specialist -\nAdvanced\nHashiCorp Certified: Terraform\nAssociate (003)\nHow to Win a Data Science\nCompetition: Learn from Top\nKagglers\nGenerative AI with Large Language\nModels\nIntroduction to Deep Learning\nPublications\nExploiting domain knowledge to\naddress class imbalance and a\nheterogeneous feature space in\nmulti-class classification\nAutoML4Clust: Efficient AutoML for\nClustering Analyses\nEfficient Exploratory Clustering\nAnalyses with Qualitative\nApproximations\nSDRank: A Deep Learning Approach\nfor Similarity Ranking of Data\nSources to Support User-Centric\nData Analysis\nML2DAC: Meta-Learning to\nDemocratize AutoML for Clustering\nAnalysis\nDennis Treder-Tschechlov,\nPhD\nData&AI || Platform Engineer || Client Engineering\nSindelfingen, Baden-Württemberg, Germany\nSummary\nI am a research scientist at the University of Stuttgart. I am\nfascinated by novel methods to automate and democratize machine\nlearning approaches. In my PhD thesis, I am focusing on automating\nthe unsupervised task of clustering analyses for novice analysts.\nThis has led to publications at international top-conferences and\njournals such as SIGMOD or VLDB-journal. I love to learn new\ntrending topics regarding data management, machine learning & AI.\nFor instance, I have completed Coursera Courses regarding Deep\nLearning and Reinforcement Learning.\nExperience\nIBM\nPlatform Engineer || Data&AI and Automation || Client Engineering\nJanuary 2025\xa0-\xa0Present\xa0(8 months)\nBöblingen, Baden-Württemberg, Germany\nInstitut für Parallele und Verteilte Systeme\nResearch Scientist for Data & AI\nMarch 2020\xa0-\xa0February 2025\xa0(5 years)\nStuttgart\n- Research on new methods for democratizing clustering analyses with\nAutoML, Meta-Learning, and Ensemble methods\n- Published 4 first-author papers, two of them at the at top-tier conferences\nSIGMOD and VLDB\n- 8 published co-author publications, two of them at the top-tier journal VLDB-\nJournal\n- Organization of events with industry partners Bosch, IBM, and Zeiss\n- Guided hands-on assignments for students about machine learning concepts\nand NoSQL systems \n- Supervision of over 20 student works, including student theses, practical\ncourses,  data science projects, and seminar works\n\xa0 Page 1 of 3\xa0 \xa0\nSoftware Campus\nLead of Software Campus Project „VALID-PARTITION“\nJanuary 2022\xa0-\xa0June 2024\xa0(2 years 6 months)\nStuttgart, Baden-Württemberg, Deutschland\n- Research grant of 100.000€ from German Federal Ministry of Education and\nResearch (BMBF)\n- Cooperation with industry partner Trumpf  ...

# %%
messages = [{"role": "user", "content": f"Generate a summary of my linkedIn Profile: {docling_text}"}]
response = openai.chat.completions.create(model="gemini-2.5-flash", messages=messages)
response.choices[0].message.content
# Out:
# "Dennis Treder-Tschechlov, PhD, is an accomplished Data & AI and Platform Engineer with a strong foundation in cutting-edge machine learning research. He is transitioning into a key role as a Platform Engineer in Data&AI and Automation at IBM starting January 2025.\n\nHis doctoral research at the University of Stuttgart focused on automating and democratizing machine learning approaches, particularly for unsupervised clustering analyses. This extensive work, specializing in AutoML, Meta-Learning, and Ensemble methods, has resulted in multiple first-author publications at prestigious international conferences and journals such as SIGMOD and VLDB.\n\nBeyond his significant academic contributions, Dennis has demonstrated strong leadership and project management skills as the Lead of the BMBF-funded 'VALID-PARTITION' project, managing budget, resources, and supervising research teams in collaboration with industry partners.\n\nEquipped with advanced certifications in IBM Machine Learning, HashiCorp Terraform, Generative AI, and Deep Learning, he possesses a robust technical skill set encompassing IBM Cloud, DevOps, and Infrastructure as Code (IaC). Passionate about learning and applying trending topics in data management, machine learning, and AI, Dennis is poised to leverage his deep research insights and engineering expertise to drive innovation in real-world applications.\n\n**Contact:** tschechd@gmail.com | www.linkedin.com/in/dennis-treder-tschechlov"

# %%
summary = response.choices[0].message.content
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
def chat_gemini(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gemini-2.5-flash", messages=messages)
    return response.choices[0].message.content

def chat_mistral(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
    response = ollama.chat.completions.create(model="mistral-small:latest", messages=messages)
    return response.choices[0].message.content

def chat_groq(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    groq = openai.OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.environ.get("GROQ_API_KEY"))
    response = groq.chat.completions.create(model="llama-3.3-70b-versatile", messages=messages)

def chat_gpt_oss(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
    response = ollama.chat.completions.create(model="gpt-oss:20b", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
chat_gpt_oss(message="hi", history=[])
# Out:
# 'Hello! 👋\n\nI’m Dennis Treder‑Tschechlov—happy to connect with you. Whether you’re curious about my research on AutoML for clustering, my work as a Platform Engineer at IBM, or how I’ve helped organizations democratize data‑science solutions, I’m here to share. What’s on your mind today?'

# %%
gr.ChatInterface(chat_gpt_oss, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7868
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7868/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GEMINI_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gemini-2.5-flash", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# "Thank you for reaching out!\n\nBased on my current background and the information I've shared, I do not hold any patents. My focus has been primarily on academic research and publishing my work in scientific conferences and journals, as well as applying these insights in practical engineering roles.\n\nIs there anything else I can help you with regarding my background or experience?"

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The agent correctly states that they do not hold any patents, which is consistent with the provided background information. The response is professional and engaging, offering further assistance, aligning with the persona's instructions.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
    response = ollama.chat.completions.create(model="gpt-oss:20b", messages=messages)
    return response.choices[0].message.content

# %%
from openai import OpenAI

def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
    response = ollama.chat.completions.create(model="gpt-oss:20b", messages=messages)
    reply =  response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7869
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7869/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Passed evaluation - returning reply
