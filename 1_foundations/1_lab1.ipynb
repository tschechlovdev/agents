# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# False

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder

from openai import OpenAI
OLLAMA_BASE_URL = "http://localhost:11434/v1"

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="anything")
MISTRAL_MODEL = "mistral-small"

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="mistral-small",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# The result of 2 + 2 is 4. Here it is:
#
# 2
# +2
# ____
# 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model=MISTRAL_MODEL,
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If the total number of points in a triangle is 180 degrees where each angle should be less than 90degrees. If I draw one hundred lines how many distinct points can you come up with?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="mistral-small",
    temperature=0,
    # other params...
)

# %%
response = llm.invoke(messages)

# %%
print(response.content)
# Out:
# To determine the number of distinct points created by drawing 100 lines, we need to consider that any two lines can intersect at most once, creating a new point.
#
# The formula for the maximum number of intersection points (P) when n lines are drawn is given by:
#
# \[ P = \binom{n}{2} \]
#
# where \(\binom{n}{2}\) is the binomial coefficient representing the number of ways to choose 2 lines out of n to form an intersection point. This can be calculated as:
#
# \[ \binom{n}{2} = \frac{n(n-1)}{2} \]
#
# For \( n = 100 \) lines, the calculation would be:
#
# \[ P = \frac{100 \times 99}{2} \]
# \[ P = \frac{9900}{2} \]
# \[ P = 4950 \]
#
# So, if you draw 100 lines, you can come up with a maximum of 4,950 distinct points.

# %%
# Ask it again

response = openai.chat.completions.create(
    model=MISTRAL_MODEL,
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# To determine the number of distinct points that can be created by intersecting lines, we need to consider the intersections formed when there are no three lines intersecting at a single point.
#
# The formula to find the maximum number of intersection points (distinct points) created by \( n \) lines is given by:
#
# \[
# P = \frac{n(n-1)}{2}
# \]
#
# Where \( P \) is the number of distinct points and \( n \) is the number of lines.
#
# Given that there are 100 lines (\( n = 100 \)), we can calculate the number of distinct points as follows:
#
# \[
# P = \frac{100 \cdot (100 - 1)}{2} = \frac{100 \cdot 99}{2}
# \]
#
# Perform the multiplication first:
#
# \[
# 100 \cdot 99 = 9900
# \]
#
# Then divide by 2:
#
# \[
# \frac{9900}{2} = 4950
# \]
#
# Thus, drawing 100 lines in a general position (where no three lines are concurrent) will result in \( 4950 \) distinct intersection points.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To determine the number of distinct points that can be created by intersecting lines, we need to consider the intersections formed when there are no three lines intersecting at a single point.
#
# The formula to find the maximum number of intersection points (distinct points) created by \( n \) lines is given by:
#
# \[
# P = \frac{n(n-1)}{2}
# \]
#
# Where \( P \) is the number of distinct points and \( n \) is the number of lines.
#
# Given that there are 100 lines (\( n = 100 \)), we can calculate the number of distinct points as follows:
#
# \[
# P = \frac{100 \cdot (100 - 1)}{2} = \frac{100 \cdot 99}{2}
# \]
#
# Perform the multiplication first:
#
# \[
# 100 \cdot 99 = 9900
# \]
#
# Then divide by 2:
#
# \[
# \frac{9900}{2} = 4950
# \]
#
# Thus, drawing 100 lines in a general position (where no three lines are concurrent) will result in \( 4950 \) distinct intersection points.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area where it might be worth for exploring an agentic AI opprotunit"}]

# Then make the first call:

response = ollama.chat.completions.create(model=MISTRAL_MODEL, messages=messages)

# Then read the business idea:

business_idea = response.choices[0].message.content


# And repeat! In the next message, include the business idea within the message

display(Markdown(business_idea))
# Out:
# To identify a potentially lucrative business area for exploring agentic AI opportunities, let's consider sectors where automation, personalization, and decision-making capabilities driven by intelligent agents can significantly enhance value. Here are a few notable areas:
#
# 1. **Healthcare**:
#    - **Use Case**: Personalized health assistants that monitor patient vitals in real-time, provide medication reminders, and alert healthcare providers of emergencies.
#    - **Benefit**: Enhanced patient care, reduced hospital readmissions, and improved treatment outcomes.
#
# 2. **Finance**:
#    - **Use Case**: Autonomous trading bots that analyze market data to make investment decisions, fraud detection systems that monitor transactions for anomalies, and chatbots that handle customer support queries.
#    - **Benefit**: Increased efficiency in financial operations, reduced risk of fraud, and improved customer satisfaction.
#
# 3. **Customer Service**:
#    - **Use Case**: Advanced virtual assistants that can manage complex customer queries across multiple channels (email, chat, phone) with high accuracy and empathy.
#    - **Benefit**: Streamlined customer support processes, reduced wait times, and enhanced customer experiences.
#
# 4. **Retail**:
#    - **Use Case**: Inventory management systems that use predictive analytics to optimize stock levels, smart recommendations engines that suggest products based on past behavior, and AI-driven personal stylists that curate outfits for customers.
#    - **Benefit**: Improved inventory turnover, increased sales through personalized shopping experiences.
#
# 5. **Logistics and Supply Chain**:
#    - **Use Case**: Autonomous logistics agents that optimize routes in real-time to reduce delivery times and costs, predictive maintenance systems that analyze sensor data from vehicles for timely repairs, and smart warehouses powered by robotic process automation (RPA) for efficient order fulfillment.
#    - **Benefit**: Enhanced operational efficiency, reduced logistics costs, and improved delivery reliability.
#
# 6. **Human Resources**:
#    - **Use Case**: AI-driven recruitment tools that screen resumes, conduct initial interviews, and match candidates with job roles best suited to their skills and experiences; performance management systems that provide personalized feedback and development plans.
#    - **Benefit**: Streamlined hiring processes, improved talent acquisition, and better employee retention.
#
# 7. **Real Estate**:
#   - **Use Case**: Property valuation tools that leverage machine learning algorithms to estimate property values accurately, smart home assistants for automated property management tasks like scheduling repairs or maintenance checks, virtual tour guides for immersive property viewing experiences.
#    - **Benefit**: Accurate property pricing, improved tenant satisfaction with efficient maintenance services, and enhanced sales through engaging digital tours.
#
# Each of these areas offers significant opportunities for innovation with agentic AI, but the specifics need to be tailored based on market needs and technological capabilities.

# %%
# First create the messages:

messages = [{"role": "user", "content": "I have a use case idea for agentic AI - present me some of the pain points in the given industry. Industry: Healthcare: Use Case: Personalized health assistants that monitor patient vitals in real-time, provide medication reminders, and alert healthcare providers of emergencies. Benefit: Enhanced patient care, reduced hospital readmissions, and improved treatment outcomes."}]

# Then make the first call:

response = ollama.chat.completions.create(model=MISTRAL_MODEL, messages=messages)

# Then read the business idea:

business_idea = response.choices[0].message.content


# And repeat! In the next message, include the business idea within the message

display(Markdown(business_idea))
# Out:
# The use case you've described for personalized health assistants in the healthcare industry has significant potential benefits. However, there are several pain points that such a system might address or need to consider:
#
# ### Pain Points in Healthcare:
# 1. **Patient Non-Compliance**:
#    - Many patients struggle with adhering to medication schedules or dietary restrictions.
#    - Elderly and chronically ill patients often forget to take their medications on time.
#
# 2. **Real-Time Monitoring Challenges**:
#    - Continuous monitoring of vital signs can be cumbersome and intrusive, making it difficult for patients to comply without feeling restricted.
#    - There is a need for reliable and unobtrusive wearable or implantable technologies.
#
# 3. **Emergency Response Delays**:
#    - Timely intervention in emergencies relies on prompt communication between patients and healthcare providers.
#    - Delays can occur due to miscommunication, limited bandwidth of communication channels, or failure to detect critical changes in patient vitals.
#
# 4. **Data Silos**:
#    - Patient data is often fragmented across different systems and institutions, making it difficult for healthcare providers to access a comprehensive view of a patient's health.
#    - Lack of interoperability between devices and systems complicates the integration of real-time data.
#
# 5. **High Readmission Rates**:
#    - Insufficient post-discharge monitoring and follow-up contribute to high readmission rates, especially among patients with chronic conditions.
#    - Effective remote monitoring could help manage post-operative care and medication adherence at home.
#
# 6. **Burnout Among Healthcare Providers**:
#    - Healthcare providers are increasingly burdened by administrative tasks and patient load.
#    - An AI assistant that can handle routine checks and alerts would free up time for more critical tasks.
#
# 7. **Cost Efficiency**:
#    - High costs associated with hospital stays, emergency visits, and readmissions.
#    - Personalized health assistants could reduce the need for expensive in-hospital care by managing patients effectively at home.
#
# 8. **Patient Engagement**:
#    - Keeping patients engaged and motivated to follow their healthcare plans can be challenging without a dedicated support system.
#    - Continual engagement through reminders, educational content, and rewards can improve patient outcomes.
#
# 9. **Privacy and Security Concerns**:
#    - Ensuring that patient data is securely stored and transmitted is crucial.
#    - Compliance with regulations like HIPAA (Health Insurance Portability and Accountability Act) is necessary to protect sensitive health information.
#
# 10. **Scalability and Implementation**:
#     - Developing a system that can be implemented across different healthcare settings, from clinics to hospitals to home care, requires significant resources.
#     - Ensuring compatibility with existing healthcare infrastructure is essential for widespread adoption.
#
# By addressing these pain points, personalized health assistants in the form of agentic AI could significantly enhance patient care, reduce healthcare costs, and improve overall treatment outcomes.

# %%
messages = [{"role": "user", "content": f"I see the following pain points in the healthcare industry. Propose an agentic AI solution to address the pain points. Pain points: {business_idea}"}]

# %%
response = ollama.chat.completions.create(model=MISTRAL_MODEL, messages=messages)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 2
#       1 response = ollama.chat.completions.create(model=MISTRAL_MODEL, messages=messages)
# ----> 2 answer = response.choices[0].messages.content
#
# File ~/Documents/Workspace/udemy/agents/.venv/lib/python3.12/site-packages/pydantic/main.py:991, in BaseModel.__getattr__(self, item)
#     988     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     989 else:
#     990     # this is the current error
# --> 991     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'Choice' object has no attribute 'messages'

# %%
answer = response.choices[0].message.content

# %%
display(Markdown(answer))
# Out:
# Addressing these diverse and complex pain points in the healthcare industry requires a multi-faceted approach using agentic AI. Here's a proposed solution:
#
# ---
#
# ### Agentic AI Solution for Personalized Health Assistants
#
# #### 1. **Patient Non-Compliance**
# - **Solution**: Implement an AI-powered companion that sends personalized reminders via wearable devices, smartphone notifications, and voice assistants (e.g., Amazon Alexa, Google Home). The system uses predictive analytics to anticipate when a patient is likely to miss a dose or meal and adjusts the frequency and type of reminders accordingly.
# - The AI can also track whether patients actually take their medications using smart pill bottles that log when they are opened.
#
# #### 2. **Real-Time Monitoring Challenges**
# - **Solution**: Develop non-intrusive wearable technology such as smartwatches or patches equipped with sensors for vital sign monitoring ( heart rate, respiration rates etc.). These devices will be integrated with the AI system to provide real-time data and alerts.
# Utilize edge computing to process data locally on wearables so it transmits to the cloud only when necessary ensuring minimal battery usage.
#
# #### 3. **Emergency Response Delays**
# - **Solution**: Employ machine learning algorithms trained to detect abnormal patterns in biometric data indicative of a medical emergency (e.g., sudden changes in heart rate, blood pressure).
# The AI will initiate automatic alerts and prioritize communication with the healthcare provider through high-speed channels like VoIP or secure instant messaging.
#
# #### 4. **Data Silos**
# - **Solution**: Use blockchain technology integrated into the AI system allows patients to access their health information (e.g., prescriptions, medical history, lab results).
# The system then uses semantic standardization and translation between different EHR systems ensuring real-time aggregation from various sources so that healthcare providers can view consolidated data on a single platform.
# #### 5. **High Readmission Rates**
# - **Solution**: Post-discharge monitoring by the AI assistant includes regular checks of medication adherence, physical therapy completion (via biometric feedback), and remote consultations with care teams through video calls or virtual patient visits. The AI alerts providers to potential issues before they escalate.
#
# #### 6. **Burnout Among Healthcare Providers**
# - **Solution**: Assign routine tasks like preliminary triage assessments, pre-consultation questionnaires, scheduling reminders, etc., to the AI assistant which frees up healthcare personnel for clinical consultations that demand expert attention.
# The system can also manage follow-up communications and schedule adjustments allowing providers to focus on more critical tasks.
#
# #### 7. **Cost Efficiency**
# - **Solution**: The AI optimizes patient care plans by suggesting cost-effective treatments and reducing unnecessary hospital visits with effective at-home monitoring and personalized coaching sessions. Cost-benefit analyses will help identify where resources are best used, reducing wastage and overuse of expensive medical procedures.
# Incorporate telehealth features to reduce the necessity for travel to hospitals for routine checkups.
#
# #### 8. **Patient Engagement**
# - **Solution**: AI-powered health coaches provide consistent engagement through personalized content (e.g., educational videos, wellness tips) that is tailored based on real-time health metrics and ongoing feedback from patients ensuring more effective healthcare plans.
#
# Use gamification methods for medication compliance, exercise regimens, diet tracking etc to enhance adherence and overall well-being.
# Continuous improvement in care protocols via patient’s feedback loops into AI system ensuring the care provided is attuned to individual needs and preferences
#
# #### 8. **Privacy and Security Concerns**
# - **Solution**: Implement robust encryption algorithms for data at rest and in transit within the wearable devices, cloud storage, and interdevice communication.
# A federated learning model can be employed that performs machine learning model training without exchanging any patient-level information ensuring compliance with regulations like The Health Insurance Portability and Accountability Act (HIPAA) by design.
#
# #### 9. **Scalability and Implementation**
# - **Solution**: Design the AI system using modular architecture comprising APIs, microservices, and containerization techniques allowing easy integration with existing hospital management systems, telemedicine providers, third-party apps for lab tests, diagnostics etc..
# Develop a standardized SDK which could be used by any medical device manufacturers and healthcare providers to quickly integrate AI assistant capabilities into new and existing devices / solutions.
# Use cloud services ensuring ease of scalability providing infrastructure flexibility across different geographies and enabling access from anywhere.
#
# ---
#
# This agentic AI solution leverages advanced technologies like machine learning, wearable tech, blockchain, and secure data protocols—combined with a user-centric approach to handle the multifaceted challenges in healthcare. This comprehensive plan enhances patient care and alleviates several administrative and logistical burdens on healthcare providers leading to cost savings and improving wellness outcomes for patients.
