# %% [markdown]
# ### Week 5 Day 4
#
# AutoGen Core - Distributed
#
# I'm only going to give a Teaser of this!!
#
# Partly because I'm unsure how relevant it is to you. If you'd like me to add more content for this, please do let me know..

# %%
from dataclasses import dataclass
from autogen_core import AgentId, MessageContext, RoutedAgent, message_handler
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.messages import TextMessage
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_ext.tools.langchain import LangChainToolAdapter
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain.agents import Tool
from IPython.display import display, Markdown
from autogen_ext.models.ollama._ollama_client import OllamaChatCompletionClient
from dotenv import load_dotenv

load_dotenv(override=True)

ALL_IN_ONE_WORKER = False

# %% [markdown]
# ### Start with our Message class

# %%
@dataclass
class Message:
    content: str

# %% [markdown]
# ### And now - a host for our distributed runtime

# %%
from autogen_ext.runtimes.grpc import GrpcWorkerAgentRuntimeHost

host = GrpcWorkerAgentRuntimeHost(address="localhost:50051")
host.start()

# %% [markdown]
# ### Let's reintroduce a tool

# %%
serper = GoogleSerperAPIWrapper()
langchain_serper =Tool(name="internet_search", func=serper.run, description="Useful for when you need to search the internet")
autogen_serper = LangChainToolAdapter(langchain_serper)

# %%
instruction1 = "To help with a decision on whether to use AutoGen in a new AI Agent project, \
please research and briefly respond with reasons in favor of choosing AutoGen; the pros of AutoGen."

instruction2 = "To help with a decision on whether to use AutoGen in a new AI Agent project, \
please research and briefly respond with reasons against choosing AutoGen; the cons of Autogen."

judge = "You must make a decision on whether to use AutoGen for a project. \
Your research team has come up with the following reasons for and against. \
Based purely on the research from your team, please respond with your decision and brief rationale."

# %% [markdown]
# ### And make some Agents

# %%
class Player1Agent(RoutedAgent):
    def __init__(self, name: str) -> None:
        super().__init__(name)
        model_client = OllamaChatCompletionClient(model="gpt-oss:20b",
        model_info={
                "vision": True,
                "function_calling": True,
                "json_output": True,
                "family": "mistral",
                "structured_output": True,
            })     
        self._delegate = AssistantAgent(name, model_client=model_client, tools=[autogen_serper], reflect_on_tool_use=True)

    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        text_message = TextMessage(content=message.content, source="user")
        response = await self._delegate.on_messages([text_message], ctx.cancellation_token)
        return Message(content=response.chat_message.content)
    
class Player2Agent(RoutedAgent):
    def __init__(self, name: str) -> None:
        super().__init__(name)
        model_client = OllamaChatCompletionClient(model="ministral-3:14b",
        model_info={
                "vision": True,
                "function_calling": True,
                "json_output": True,
                "family": "mistral",
                "structured_output": True,
            })     
        self._delegate = AssistantAgent(name, model_client=model_client, tools=[autogen_serper], reflect_on_tool_use=True)

    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        text_message = TextMessage(content=message.content, source="user")
        response = await self._delegate.on_messages([text_message], ctx.cancellation_token)
        return Message(content=response.chat_message.content)
    
class Judge(RoutedAgent):
    def __init__(self, name: str) -> None:
        super().__init__(name)
        model_client = OllamaChatCompletionClient(model="gpt-oss:20b",
        model_info={
                "vision": True,
                "function_calling": True,
                "json_output": True,
                "family": "mistral",
                "structured_output": True,
            })     
        self._delegate = AssistantAgent(name, model_client=model_client)
        
    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        message1 = Message(content=instruction1)
        message2 = Message(content=instruction2)
        inner_1 = AgentId("player1", "default")
        inner_2 = AgentId("player2", "default")
        response1 = await self.send_message(message1, inner_1)
        response2 = await self.send_message(message2, inner_2)
        result = f"## Pros of AutoGen:\n{response1.content}\n\n## Cons of AutoGen:\n{response2.content}\n\n"
        judgement = f"{judge}\n{result}Respond with your decision and brief explanation"
        message = TextMessage(content=judgement, source="user")
        response = await self._delegate.on_messages([message], ctx.cancellation_token)
        return Message(content=result + "\n\n## Decision:\n\n" + response.chat_message.content)

# %%
from autogen_ext.runtimes.grpc import GrpcWorkerAgentRuntime

if ALL_IN_ONE_WORKER:

    worker = GrpcWorkerAgentRuntime(host_address="localhost:50051")
    await worker.start()

    await Player1Agent.register(worker, "player1", lambda: Player1Agent("player1"))
    await Player2Agent.register(worker, "player2", lambda: Player2Agent("player2"))
    await Judge.register(worker, "judge", lambda: Judge("judge"))

    agent_id = AgentId("judge", "default")

else:

    worker1 = GrpcWorkerAgentRuntime(host_address="localhost:50051")
    await worker1.start()
    await Player1Agent.register(worker1, "player1", lambda: Player1Agent("player1"))

    worker2 = GrpcWorkerAgentRuntime(host_address="localhost:50051")
    await worker2.start()
    await Player2Agent.register(worker2, "player2", lambda: Player2Agent("player2"))

    worker = GrpcWorkerAgentRuntime(host_address="localhost:50051")
    await worker.start()
    await Judge.register(worker, "judge", lambda: Judge("judge"))
    agent_id = AgentId("judge", "default")
# Out:
# ---------------------------------------------------------------------------
# AioRpcError                               Traceback (most recent call last)
# Cell In[33], line 18
#      16 worker1 = GrpcWorkerAgentRuntime(host_address="localhost:50051")
#      17 await worker1.start()
# ---> 18 await Player1Agent.register(worker1, "player1", lambda: Player1Agent("player1"))
#      20 worker2 = GrpcWorkerAgentRuntime(host_address="localhost:50051")
#      21 await worker2.start()
#
# File ~/Documents/4_Workspace/udemy/agents/.venv/lib/python3.12/site-packages/autogen_core/_base_agent.py:225, in BaseAgent.register(cls, runtime, type, factory, skip_class_subscriptions, skip_direct_message_subscription)
#     214 @classmethod
#     215 async def register(
#     216     cls,
#    (...)    222     skip_direct_message_subscription: bool = False,
#     223 ) -> AgentType:
#     224     agent_type = AgentType(type)
# --> 225     agent_type = await runtime.register_factory(type=agent_type, agent_factory=factory, expected_class=cls)
#     226     if not skip_class_subscriptions:
#     227         with SubscriptionInstantiationContext.populate_context(agent_type):
#
# File ~/Documents/4_Workspace/udemy/agents/.venv/lib/python3.12/site-packages/autogen_ext/runtimes/grpc/_worker_runtime.py:742, in GrpcWorkerAgentRuntime.register_factory(self, type, agent_factory, expected_class)
#     740 self._agent_factories[type.type] = factory_wrapper
#     741 # Send the registration request message to the host.
# --> 742 await self._register_agent_type(type.type)
#     744 return type
#
# File ~/Documents/4_Workspace/udemy/agents/.venv/lib/python3.12/site-packages/autogen_ext/runtimes/grpc/_worker_runtime.py:709, in GrpcWorkerAgentRuntime._register_agent_type(self, agent_type)
#     707     raise RuntimeError("Host connection is not set.")
#     708 message = agent_worker_pb2.RegisterAgentTypeRequest(type=agent_type)
# --> 709 _response: agent_worker_pb2.RegisterAgentTypeResponse = await self._host_connection.stub.RegisterAgent(
#     710     message, metadata=self._host_connection.metadata
#     711 )
#
# File ~/Documents/4_Workspace/udemy/agents/.venv/lib/python3.12/site-packages/grpc/aio/_call.py:327, in _UnaryResponseMixin.__await__(self)
#     325         raise asyncio.CancelledError()
#     326     else:
# --> 327         raise _create_rpc_error(
#     328             self._cython_call._initial_metadata,
#     329             self._cython_call._status,
#     330         )
#     331 else:
#     332     return response
#
# AioRpcError: <AioRpcError of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "Agent type player1 already registered with client 65cd0ab2-77b4-47ba-a96e-e8d8b775cb77."
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"Agent type player1 already registered with client 65cd0ab2-77b4-47ba-a96e-e8d8b775cb77.", grpc_status:3, created_time:"2026-01-13T12:00:21.056478+01:00"}"
# >

# %%
response = await worker.send_message(Message(content="Go!"), agent_id)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 response = await worker.send_message(Message(content="Go!"), agent_id)
#
# File ~/Documents/4_Workspace/udemy/agents/.venv/lib/python3.12/site-packages/autogen_ext/runtimes/grpc/_worker_runtime.py:411, in GrpcWorkerAgentRuntime.send_message(self, message, recipient, sender, cancellation_token, message_id)
#     409 task.add_done_callback(self._raise_on_exception)
#     410 task.add_done_callback(self._background_tasks.discard)
# --> 411 return await future
#
# Exception: Error code: 401 - {'error': {'message': 'Incorrect API key provided: ollama. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
display(Markdown(response.content))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 display(Markdown(response.content))
#
# NameError: name 'response' is not defined

# %%
await worker.stop()
if not ALL_IN_ONE_WORKER:
    await worker1.stop()
    await worker2.stop()

# %%
await host.stop()
